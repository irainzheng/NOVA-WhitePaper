# %% [markdown]
# # NOVA Macro Simulation V1.5
#
# Whitepaper sections 21.7 / 21.8. Same logic as `nova_macro.py`.

# %%
from pathlib import Path
import sys
sys.path.insert(0, str(Path('.').resolve()))
from nova_macro import load_params, simulate, plot

params = load_params(Path('params/baseline_v1.5.yaml'))
result = simulate(params, years=20)
result['summary']

# %%
import pandas as pd
df = pd.DataFrame(result['rows'])
df.tail(12)

# %%
plot(result, Path('output/macro_v1.5.png'))
